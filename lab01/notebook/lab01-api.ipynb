# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import io
import requests
import json

#busca 1 no dataset FDA

#medicamentos de via oral
url = "https://api.fda.gov/drug/ndc.json?limit=3&search=route.exact:ORAL"
js = requests.get(url).content
print(js.decode("utf-8"))

#medicamentos com nome generico ibuprofeno
url = "https://api.fda.gov/drug/ndc.json?limit=3&search=generic_name.exact:IBUPROFEN"
js = requests.get(url).content
print(js.decode("utf-8"))

#busca 2
# Out:
# {
#   "meta": {
#     "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#     "terms": "https://open.fda.gov/terms/",
#     "license": "https://open.fda.gov/license/",
#     "last_updated": "2021-08-20",
#     "results": {
#       "skip": 0,
#       "limit": 3,
#       "total": 61005
#     }
#   },
#   "results": [
#     {
#       "product_ndc": "72189-160",
#       "generic_name": "LEVOTHYROXINE SODIUM",
#       "labeler_name": "DIRECT RX",
#       "brand_name": "LEVOTHYROXINE SODIUM",
#       "active_ingredients": [
#         {
#           "name": "LEVOTHYROXINE SODIUM",
#           "strength": "125 ug/1"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "72189-160-30",
#           "description": "30 TABLET in 1 BOTTLE (72189-160-30)",
#           "marketing_start_date": "20201201",
#           "sample": false
#         }
#       ],
#       "listing_expiration_date": "20221231",
#       "openfda": {
#         "manufacturer_name": [
#           "DIRECT RX"
#         ],
#         "spl_set_id": [
#           "a5f15022-1166-09fe-e053-2a95a90aa218"
#         ],
#         "unii": [
#           "9J765S329G"
#         ]
#       },
#       "marketing_category": "NDA",
#       "dosage_form": "TABLET",
#       "spl_id": "c9dafd0b-f52b-5bf8-e053-2995a90a0a82",
#       "product_type": "HUMAN PRESCRIPTION DRUG",
#       "route": [
#         "ORAL"
#       ],
#       "marketing_start_date": "20201201",
#       "product_id": "72189-160_c9dafd0b-f52b-5bf8-e053-2995a90a0a82",
#       "application_number": "NDA021116",
#       "brand_name_base": "LEVOTHYROXINE SODIUM",
#       "pharm_class": [
#         "l-Thyroxine [EPC]",
#         "Thyroxine [CS]"
#       ]
#     },
#     {
#       "product_ndc": "71919-234",
#       "generic_name": "CROTALUS DURISSUS TERRIFICUS VENOM",
#       "labeler_name": "Washington Homeopathic Products",
#       "brand_name": "Crotalus cascavella",
#       "active_ingredients": [
#         {
#           "name": "CROTALUS DURISSUS TERRIFICUS VENOM",
#           "strength": "30 [hp_C]/mL"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "71919-234-07",
#           "description": "15 mL in 1 VIAL, GLASS (71919-234-07)",
#           "marketing_start_date": "20130605",
#           "sample": false
#         },
#         {
#           "package_ndc": "71919-234-08",
#           "description": "30 mL in 1 VIAL, GLASS (71919-234-08)",
#           "marketing_start_date": "20130605",
#           "sample": false
#         },
#         {
#           "package_ndc": "71919-234-09",
#           "description": "50 mL in 1 BOTTLE, GLASS (71919-234-09)",
#           "marketing_start_date": "20130605",
#           "sample": false
#         },
#         {
#           "package_ndc": "71919-234-10",
#           "description": "100 mL in 1 BOTTLE, GLASS (71919-234-10)",
#           "marketing_start_date": "20130605",
#           "sample": false
#         }
#       ],
#       "listing_expiration_date": "20211231",
#       "openfda": {
#         "manufacturer_name": [
#           "Washington Homeopathic Products"
#         ],
#         "spl_set_id": [
#           "7e6d0b1f-ed80-4f56-8077-f950d8d9bffa"
#         ],
#         "is_original_packager": [
#           true
#         ],
#         "upc": [
#           "0740640292884"
#         ],
#         "unii": [
#           "2XF6I0446G"
#         ]
#       },
#       "marketing_category": "UNAPPROVED HOMEOPATHIC",
#       "dosage_form": "LIQUID",
#       "spl_id": "7e48d272-8551-3797-e053-2a91aa0a5e42",
#       "product_type": "HUMAN OTC DRUG",
#       "route": [
#         "ORAL"
#       ],
#       "marketing_start_date": "20130605",
#       "product_id": "71919-234_7e48d272-8551-3797-e053-2a91aa0a5e42",
#       "brand_name_base": "Crotalus cascavella"
#     },
#     {
#       "product_ndc": "71919-479",
#       "generic_name": "SODIUM HYPOCHLORITE",
#       "labeler_name": "Washington Homeopathic Products",
#       "brand_name": "Nat hypochlorosum",
#       "active_ingredients": [
#         {
#           "name": "SODIUM HYPOCHLORITE",
#           "strength": "30 [hp_C]/mL"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "71919-479-07",
#           "description": "15 mL in 1 VIAL, GLASS (71919-479-07)",
#           "marketing_start_date": "20120601",
#           "sample": false
#         },
#         {
#           "package_ndc": "71919-479-08",
#           "description": "30 mL in 1 VIAL, GLASS (71919-479-08)",
#           "marketing_start_date": "20120601",
#           "sample": false
#         },
#         {
#           "package_ndc": "71919-479-09",
#           "description": "50 mL in 1 BOTTLE, GLASS (71919-479-09)",
#           "marketing_start_date": "20120601",
#           "sample": false
#         },
#         {
#           "package_ndc": "71919-479-10",
#           "description": "100 mL in 1 BOTTLE, GLASS (71919-479-10)",
#           "marketing_start_date": "20120601",
#           "sample": false
#         }
#       ],
#       "listing_expiration_date": "20211231",
#       "openfda": {
#         "manufacturer_name": [
#           "Washington Homeopathic Products"
#         ],
#         "spl_set_id": [
#           "10fa34b6-9772-44b1-8312-e014f19a5e6d"
#         ],
#         "is_original_packager": [
#           true
#         ],
#         "unii": [
#           "DY38VHM5OD"
#         ]
#       },
#       "marketing_category": "UNAPPROVED HOMEOPATHIC",
#       "dosage_form": "LIQUID",
#       "spl_id": "7e58bc5a-9e0f-3e20-e053-2991aa0a4d35",
#       "product_type": "HUMAN OTC DRUG",
#       "route": [
#         "ORAL"
#       ],
#       "marketing_start_date": "20120601",
#       "product_id": "71919-479_7e58bc5a-9e0f-3e20-e053-2991aa0a4d35",
#       "brand_name_base": "Nat hypochlorosum"
#     }
#   ]
# }
# {
#   "meta": {
#     "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#     "terms": "https://open.fda.gov/terms/",
#     "license": "https://open.fda.gov/license/",
#     "last_updated": "2021-08-20",
#     "results": {
#       "skip": 0,
#       "limit": 3,
#       "total": 111
#     }
#   },
#   "results": [
#     {
#       "product_ndc": "63868-796",
#       "generic_name": "IBUPROFEN",
#       "labeler_name": "Chain Drug Marketing Association, Inc.",
#       "brand_name": "Childrens Ibuprofen Oral Suspension",
#       "active_ingredients": [
#         {
#           "name": "IBUPROFEN",
#           "strength": "100 mg/5mL"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "63868-796-04",
#           "description": "1 BOTTLE in 1 CARTON (63868-796-04)  > 118 mL in 1 BOTTLE",
#           "marketing_start_date": "20201215",
#           "sample": false
#         }
#       ],
#       "listing_expiration_date": "20211231",
#       "openfda": {
#         "manufacturer_name": [
#           "Chain Drug Marketing Association, Inc."
#         ],
#         "rxcui": [
#           "197803"
#         ],
#         "spl_set_id": [
#           "f0959369-890e-403e-8a98-4eda340a0783"
#         ],
#         "is_original_packager": [
#           true
#         ],
#         "nui": [
#           "N0000000160",
#           "M0001335",
#           "N0000175722"
#         ],
#         "pharm_class_moa": [
#           "Cyclooxygenase Inhibitors [MoA]"
#         ],
#         "pharm_class_cs": [
#           "Anti-Inflammatory Agents, Non-Steroidal [CS]"
#         ],
#         "pharm_class_epc": [
#           "Nonsteroidal Anti-inflammatory Drug [EPC]"
#         ],
#         "unii": [
#           "WK2XYI10QM"
#         ]
#       },
#       "marketing_category": "ANDA",
#       "dosage_form": "SUSPENSION",
#       "spl_id": "6f842ba1-e583-455b-a69b-ed881481f4ac",
#       "product_type": "HUMAN OTC DRUG",
#       "route": [
#         "ORAL"
#       ],
#       "marketing_start_date": "20201215",
#       "product_id": "63868-796_6f842ba1-e583-455b-a69b-ed881481f4ac",
#       "application_number": "ANDA210602",
#       "brand_name_base": "Childrens Ibuprofen Oral Suspension"
#     },
#     {
#       "product_ndc": "67751-148",
#       "generic_name": "IBUPROFEN",
#       "labeler_name": "Navajo Manufacturing Company Inc.",
#       "brand_name": "Advil Liquigels",
#       "active_ingredients": [
#         {
#           "name": "IBUPROFEN",
#           "strength": "200 mg/1"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "67751-148-01",
#           "description": "1 POUCH in 1 CARTON (67751-148-01)  > 4 CAPSULE, LIQUID FILLED in 1 POUCH",
#           "marketing_start_date": "20160920",
#           "sample": false
#         }
#       ],
#       "listing_expiration_date": "20211231",
#       "openfda": {
#         "manufacturer_name": [
#           "Navajo Manufacturing Company Inc."
#         ],
#         "rxcui": [
#           "310964",
#           "731533"
#         ],
#         "spl_set_id": [
#           "e2c09216-fd63-4d50-9878-62b36236b2e7"
#         ],
#         "nui": [
#           "N0000000160",
#           "M0001335",
#           "N0000175722"
#         ],
#         "pharm_class_moa": [
#           "Cyclooxygenase Inhibitors [MoA]"
#         ],
#         "pharm_class_cs": [
#           "Anti-Inflammatory Agents, Non-Steroidal [CS]"
#         ],
#         "pharm_class_epc": [
#           "Nonsteroidal Anti-inflammatory Drug [EPC]"
#         ],
#         "unii": [
#           "WK2XYI10QM"
#         ]
#       },
#       "marketing_category": "NDA",
#       "dosage_form": "CAPSULE, LIQUID FILLED",
#       "spl_id": "96890c35-e743-fdfd-e053-2a95a90a77a9",
#       "product_type": "HUMAN OTC DRUG",
#       "route": [
#         "ORAL"
#       ],
#       "marketing_start_date": "20160920",
#       "product_id": "67751-148_96890c35-e743-fdfd-e053-2a95a90a77a9",
#       "application_number": "NDA020402",
#       "brand_name_base": "Advil Liquigels"
#     },
#     {
#       "product_ndc": "63940-199",
#       "marketing_end_date": "20211231",
#       "generic_name": "IBUPROFEN",
#       "labeler_name": "Harmon Stores",
#       "brand_name": "Ibuprofen",
#       "active_ingredients": [
#         {
#           "name": "IBUPROFEN",
#           "strength": "200 mg/1"
#         }
#       ],
#       "finished": true,
#       "packaging": [
#         {
#           "package_ndc": "63940-199-20",
#           "description": "1 BOTTLE, PLASTIC in 1 BOX (63940-199-20)  > 20 CAPSULE, LIQUID FILLED in 1 BOTTLE, PLASTIC",
#           "marketing_start_date": "20140831",
#           "marketing_end_date": "20211231",
#           "sample": false
#         },
#         {
#           "package_ndc": "63940-199-40",
#           "description": "1 BOTTLE, PLASTIC in 1 BOX (63940-199-40)  > 40 CAPSULE, LIQUID FILLED in 1 BOTTLE, PLASTIC",
#           "marketing_start_date": "20140831",
#           "marketing_end_date": "20211231",
#           "sample": false
#         }
#       ],
#       "openfda": {
#         "manufacturer_name": [
#           "Harmon Stores"
#         ],
#         "rxcui": [
#           "310964"
#         ],
#         "spl_set_id": [
#           "1f55261b-5910-4f08-909b-498db4475e03"
#         ],
#         "is_original_packager": [
#           true
#         ],
#         "upc": [
#           "0359726121446"
#         ],
#         "nui": [
#           "N0000000160",
#           "M0001335",
#           "N0000175722"
#         ],
#         "pharm_class_moa": [
#           "Cyclooxygenase Inhibitors [MoA]"
#         ],
#         "pharm_class_cs": [
#           "Anti-Inflammatory Agents, Non-Steroidal [CS]"
#         ],
#         "pharm_class_epc": [
#           "Nonsteroidal Anti-inflammatory Drug [EPC]"
#         ],
#         "unii": [
#           "WK2XYI10QM"
#         ]
#       },
#       "marketing_category": "ANDA",
#       "dosage_form": "CAPSULE, LIQUID FILLED",
#       "spl_id": "bf5ee32c-7433-4031-a971-a73d0aa425d7",
#       "product_type": "HUMAN OTC DRUG",
#       "route": [
#         "ORAL"
#       ],
#       "marketing_start_date": "20140831",
#       "product_id": "63940-199_bf5ee32c-7433-4031-a971-a73d0aa425d7",
#       "application_number": "ANDA078682",
#       "brand_name_base": "Ibuprofen"
#     }
#   ]
# }

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
